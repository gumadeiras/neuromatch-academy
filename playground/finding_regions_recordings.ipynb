# %% [markdown]
# dat['mouse_name']: mouse name
#
# dat['date_exp']: when a session was performed
#
# dat['spks']: neurons by trials by time bins.
#
# dat['brain_area']: brain area for each neuron recorded.
#
# dat['contrast_right']: contrast level for the right stimulus, which is always contralateral to the recorded brain areas.
#
# dat['contrast_left']: contrast level for left stimulus.
#
# dat['gocue']: when the go cue sound was played.
#
# dat['response_times']: when the response was registered, which has to be after the go cue. The mouse can turn the wheel before the go cue (and nearly always does!), but the stimulus on the screen won't move before the go cue.
#
# dat['response']: which side the response was (-1, 0, 1). When the right-side stimulus had higher contrast, the correct choice was -1. 0 is a no go response.
#
# dat['feedback_time']: when feedback was provided.
#
# dat['feedback_type']: if the feedback was positive (+1, reward) or negative (-1, white noise burst).
#
# dat['wheel']: exact position of the wheel that the mice uses to make a response, binned at 10ms.
#
# dat['pupil']: pupil area (noisy, because pupil is very small) + pupil horizontal and vertical position.
#
# dat['lfp']: recording of the local field potential in each brain area from this experiment, binned at 10ms.
#
# dat['brain_area_lfp']: brain area names for the LFP channels.
#
# dat['trough_to_peak']: measures the width of the action potential waveform for each neuron. Widths <=10 samples are "putative fast spiking neurons".
#
# dat['waveform_w']: temporal components of spike waveforms. w@u reconstructs the time by channels action potential shape.
#
# dat['waveform_u]: spatial components of spike waveforms.
#
# dat['%X%_passive']: same as above for X = {spks, lfp, pupil, wheel, contrast_left, contrast_right} but for passive trials at the end of the recording when the mouse was no longer engaged and stopped making responses.

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
from functions.plotting import *
from functions.filtering import *

# %%
# load data from steinmetz dir
alldat = np.load('../steinmetz/steinmetz_part0.npz', allow_pickle=True)['dat']
alldat = np.hstack((alldat, np.load('../steinmetz/steinmetz_part1.npz', allow_pickle=True)['dat']))
alldat = np.hstack((alldat, np.load('../steinmetz/steinmetz_part2.npz', allow_pickle=True)['dat']))
print(f"number of recordings: {alldat.shape}")
# Out:
# number of recordings: (39,)

# %%
# recorded regions and number of animals animals
regions_recorded(alldat)
# Out:
# [('ACA', 11),
#  ('ACB', 3),
#  ('APN', 2),
#  ('AUD', 1),
#  ('BLA', 2),
#  ('BMA', 1),
#  ('CA', 1),
#  ('CA1', 21),
#  ('CA2', 1),
#  ('CA3', 10),
#  ('CL', 1),
#  ('COA', 1),
#  ('CP', 5),
#  ('DG', 16),
#  ('DP', 1),
#  ('EP', 1),
#  ('EPd', 1),
#  ('GPe', 3),
#  ('IC', 1),
#  ('ILA', 3),
#  ('LD', 6),
#  ('LGd', 10),
#  ('LH', 2),
#  ('LP', 11),
#  ('LS', 3),
#  ('LSc', 1),
#  ('LSr', 4),
#  ('MB', 6),
#  ('MD', 3),
#  ('MEA', 1),
#  ('MG', 2),
#  ('MOp', 3),
#  ('MOs', 18),
#  ('MRN', 11),
#  ('MS', 1),
#  ('NB', 1),
#  ('OLF', 3),
#  ('ORB', 5),
#  ('ORBm', 1),
#  ('OT', 1),
#  ('PAG', 3),
#  ('PIR', 1),
#  ('PL', 10),
#  ('PO', 5),
#  ('POL', 3),
#  ('POST', 4),
#  ('PT', 1),
#  ('RN', 1),
#  ('RSP', 9),
#  ('RT', 2),
#  ('SCig', 4),
#  ('SCm', 7),
#  ('SCs', 4),
#  ('SCsg', 6),
#  ('SI', 1),
#  ('SNr', 4),
#  ('SPF', 2),
#  ('SSp', 5),
#  ('SSs', 1),
#  ('SUB', 9),
#  ('TH', 8),
#  ('TT', 4),
#  ('VAL', 1),
#  ('VISa', 5),
#  ('VISam', 11),
#  ('VISl', 3),
#  ('VISp', 12),
#  ('VISpm', 4),
#  ('VISrl', 2),
#  ('VPL', 4),
#  ('VPM', 4),
#  ('ZI', 4),
#  ('root', 34)]

# %%
# animal index and number of neurons for a region
region = 'VISp'
recordings_with_region(alldat, region)
# Out:
# array([[  0, 178],
#        [  2, 114],
#        [  3,  39],
#        [  7,  48],
#        [  9, 105],
#        [ 11,  66],
#        [ 13,  42],
#        [ 19, 122],
#        [ 21, 133],
#        [ 24,  94],
#        [ 25, 162],
#        [ 38,  15]])

# %%
# regions and number of neurons recorded for each animal
rgs = regions_recorded_per_animal(alldat)
for idx, rg in enumerate(rgs):
    print(f"recording: {rg[0]}\n",
          f"regions: {rg[1]}\n\n")
# Out:
# recording: 0
#  regions: [('ACA', 109), ('CA3', 68), ('DG', 34), ('LS', 139), ('MOs', 113), ('SUB', 75), ('VISp', 178), ('root', 18)]
#
#
# recording: 1
#  regions: [('CA1', 190), ('POST', 191), ('VISl', 231), ('VISpm', 302), ('root', 156)]
#
#
# recording: 2
#  regions: [('CA1', 42), ('DG', 34), ('LP', 4), ('MG', 137), ('MRN', 41), ('NB', 43), ('POST', 63), ('SPF', 15), ('VISam', 114), ('VISp', 114), ('root', 12)]
#
#
# recording: 3
#  regions: [('ACA', 304), ('CA1', 98), ('DG', 144), ('LGd', 140), ('LSr', 435), ('MOs', 92), ('SUB', 108), ('TH', 256), ('VISa', 81), ('VISp', 39), ('VPL', 72)]
#
#
# recording: 4
#  regions: [('ACA', 53), ('CA1', 28), ('DG', 16), ('MOs', 29), ('OLF', 181), ('ORB', 32), ('PL', 14), ('SUB', 101), ('VISa', 99), ('root', 524)]
#
#
# recording: 5
#  regions: [('AUD', 246), ('CA1', 36), ('SSp', 11), ('TH', 248), ('root', 628)]
#
#
# recording: 6
#  regions: [('CA3', 130), ('CP', 59), ('EPd', 52), ('LD', 42), ('PIR', 67), ('SSp', 39), ('VPL', 106), ('root', 89)]
#
#
# recording: 7
#  regions: [('CA1', 56), ('CA3', 17), ('DG', 33), ('ILA', 144), ('LD', 41), ('LP', 120), ('LSr', 3), ('MOs', 112), ('PL', 144), ('PO', 255), ('SUB', 34), ('TT', 82), ('VISa', 63), ('VISp', 48), ('root', 4)]
#
#
# recording: 8
#  regions: [('CA1', 90), ('CA3', 86), ('LD', 79), ('LSr', 33), ('ORBm', 122), ('PL', 50), ('TH', 52), ('TT', 55), ('VISam', 38), ('VISl', 104), ('VPL', 73), ('root', 6)]
#
#
# recording: 9
#  regions: [('CA1', 76), ('DG', 73), ('GPe', 63), ('MB', 275), ('MRN', 72), ('POL', 154), ('POST', 41), ('SCm', 23), ('SCsg', 19), ('VISl', 99), ('VISp', 105), ('VISrl', 136), ('root', 36)]
#
#
# recording: 10
#  regions: [('CP', 275), ('LSc', 72), ('LSr', 4), ('MOp', 447), ('PT', 45), ('root', 14)]
#
#
# recording: 11
#  regions: [('ACA', 16), ('CA1', 50), ('DG', 65), ('LGd', 11), ('LH', 18), ('MD', 126), ('MOs', 6), ('PL', 56), ('SUB', 105), ('VISam', 79), ('VISp', 66), ('root', 100)]
#
#
# recording: 12
#  regions: [('ACA', 58), ('CA1', 34), ('DG', 17), ('LGd', 150), ('MB', 63), ('MOs', 46), ('MRN', 51), ('MS', 23), ('PL', 184), ('RN', 58), ('SCm', 45), ('SCs', 32), ('VISam', 34), ('ZI', 15), ('root', 173)]
#
#
# recording: 13
#  regions: [('CA1', 99), ('MOs', 186), ('MRN', 72), ('ORB', 170), ('PAG', 14), ('RSP', 85), ('SCm', 48), ('SCs', 37), ('VISp', 42), ('root', 3)]
#
#
# recording: 14
#  regions: [('BLA', 132), ('CA3', 3), ('GPe', 142), ('LGd', 121), ('MB', 45), ('VPM', 162), ('ZI', 55), ('root', 83)]
#
#
# recording: 15
#  regions: [('CA3', 21), ('LGd', 73), ('MB', 77), ('SSp', 24), ('SSs', 120), ('TH', 159)]
#
#
# recording: 16
#  regions: [('LD', 12), ('MEA', 41), ('RT', 44), ('VPL', 50), ('VPM', 60), ('root', 358)]
#
#
# recording: 17
#  regions: [('ACB', 155), ('CA3', 35), ('CP', 158), ('LGd', 89), ('OT', 26), ('SI', 48), ('SNr', 129), ('TH', 175), ('ZI', 175), ('root', 99)]
#
#
# recording: 18
#  regions: [('APN', 185), ('CA1', 66), ('DG', 41), ('LP', 32), ('POL', 22), ('SUB', 57), ('VISam', 111), ('VISpm', 68), ('root', 24)]
#
#
# recording: 19
#  regions: [('CA1', 37), ('DG', 45), ('LGd', 147), ('LP', 30), ('MG', 158), ('SPF', 38), ('SUB', 51), ('TH', 191), ('VISa', 78), ('VISp', 122), ('root', 2)]
#
#
# recording: 20
#  regions: [('LD', 100), ('MOp', 166), ('SSp', 211), ('VAL', 83), ('root', 18)]
#
#
# recording: 21
#  regions: [('ACA', 32), ('ACB', 92), ('IC', 58), ('MOs', 65), ('MRN', 112), ('PL', 48), ('RSP', 82), ('SCsg', 14), ('TT', 10), ('VISp', 133)]
#
#
# recording: 22
#  regions: [('CA1', 82), ('DG', 75), ('LP', 164), ('PO', 202), ('VISam', 190), ('root', 555)]
#
#
# recording: 23
#  regions: [('CA1', 187), ('CA2', 115), ('MRN', 80), ('RSP', 181), ('SCig', 366), ('SCsg', 84), ('VISpm', 146), ('VISrl', 150), ('root', 28)]
#
#
# recording: 24
#  regions: [('ACA', 25), ('DP', 39), ('ILA', 80), ('MOs', 80), ('MRN', 182), ('PL', 60), ('RSP', 57), ('SCig', 186), ('SCsg', 36), ('TT', 34), ('VISp', 94), ('root', 12)]
#
#
# recording: 25
#  regions: [('MOs', 166), ('MRN', 217), ('SCig', 190), ('VISp', 162), ('root', 321)]
#
#
# recording: 26
#  regions: [('ACA', 67), ('ACB', 90), ('CA1', 20), ('DG', 20), ('LD', 24), ('LP', 30), ('MOs', 97), ('PL', 13), ('PO', 96), ('VISam', 103), ('root', 3)]
#
#
# recording: 27
#  regions: [('APN', 62), ('CA1', 56), ('DG', 15), ('LP', 15), ('MRN', 67), ('POL', 39), ('RSP', 135), ('SCig', 65), ('SCsg', 12), ('VISpm', 71), ('root', 12)]
#
#
# recording: 28
#  regions: [('CP', 340), ('MOp', 180), ('SSp', 230)]
#
#
# recording: 29
#  regions: [('ACA', 18), ('CA1', 36), ('CL', 32), ('DG', 67), ('LP', 209), ('LS', 47), ('MD', 155), ('MOs', 38), ('PO', 94), ('RSP', 60), ('SUB', 61), ('VISa', 19), ('VPM', 100), ('root', 6)]
#
#
# recording: 30
#  regions: [('CA3', 43), ('MOs', 281), ('OLF', 78), ('ORB', 291), ('POST', 17), ('SCm', 41), ('SNr', 117), ('TH', 109)]
#
#
# recording: 31
#  regions: [('MOs', 69), ('MRN', 23), ('OLF', 4), ('ORB', 153), ('PAG', 41), ('RSP', 79), ('SCm', 56), ('SCs', 73), ('root', 24)]
#
#
# recording: 32
#  regions: [('CA1', 4), ('CA3', 7), ('CP', 383), ('EP', 91), ('LGd', 34), ('SNr', 15), ('VPM', 31), ('ZI', 44), ('root', 4)]
#
#
# recording: 33
#  regions: [('BMA', 104), ('COA', 316), ('LP', 19), ('MB', 66), ('PO', 45), ('RT', 129), ('root', 102)]
#
#
# recording: 34
#  regions: [('ACA', 74), ('CA1', 24), ('DG', 28), ('LGd', 8), ('LH', 6), ('LP', 66), ('LS', 219), ('MD', 116), ('MOs', 34), ('RSP', 72), ('TH', 67), ('VISam', 75), ('root', 6)]
#
#
# recording: 35
#  regions: [('CA', 193), ('MOs', 41), ('MRN', 99), ('PL', 121), ('SCm', 56), ('SCsg', 13), ('VISam', 53), ('root', 104)]
#
#
# recording: 36
#  regions: [('MB', 348), ('MOs', 233), ('ORB', 166), ('PAG', 85), ('RSP', 16), ('SCm', 87), ('SCs', 15), ('VISam', 77), ('root', 28)]
#
#
# recording: 37
#  regions: [('BLA', 185), ('CA3', 84), ('GPe', 87), ('LGd', 109), ('SNr', 45), ('root', 295)]
#
#
# recording: 38
#  regions: [('ACA', 83), ('CA1', 47), ('DG', 69), ('ILA', 187), ('LP', 59), ('MOs', 54), ('PL', 173), ('SUB', 93), ('VISam', 126), ('VISp', 15), ('root', 442)]
